# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:SecureP%40sw0rd%21123@localhost:3306/united_nations

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Northern Africa and Western Asia', 'Western Asia', 'Yemen', 2015, Decimal('59.00'), Decimal('56.33'), None, None, None, None),
#  ('Northern Africa and Western Asia', 'Western Asia', 'Yemen', 2016, Decimal('59.67'), Decimal('56.33'), None, None, None, None),
#  ('Northern Africa and Western Asia', 'Western Asia', 'Yemen', 2017, Decimal('60.33'), Decimal('56.67'), None, None, None, None),
#  ('Northern Africa and Western Asia', 'Western Asia', 'Yemen', 2018, Decimal('61.33'), Decimal('56.67'), None, None, None, None),
#  ('Northern Africa and Western Asia', 'Western Asia', 'Yemen', 2019, Decimal('62.33'), Decimal('57.00'), None, None, None, None)]

# %% [markdown]
# ## 1. Create a table named Geographic_Location.

# %%
# %%sql
#
# CREATE TABLE Geographic_Location (
#     Country_name VARCHAR(255) PRIMARY KEY,
#     Region VARCHAR(255),
#     Sub_region VARCHAR(255),
#     Land_area DECIMAL(11, 2)
# )
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 0 rows affected.
# []

# %% [markdown]
# ## 2. Extract the relevant columns from the Access_to_Basic_Services table.

# %%
# %%sql
#
# INSERT INTO Geographic_Location (Country_name, Region, Sub_region, Land_area)
# SELECT Country_name, Region, Sub_region,
# AVG(Land_area)
# FROM Access_to_Basic_Services
# GROUP BY Country_name, Region, Sub_region
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 182 rows affected.
# []

# %%
# %sql SELECT * FROM Geographic_Location;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 182 rows affected.
# [('Afghanistan', 'Central and Southern Asia', 'Southern Asia', Decimal('652230.00')),
#  ('Algeria', 'Northern Africa and Western Asia', 'Northern Africa', Decimal('2381741.00')),
#  ('American Samoa', 'Oceania', 'Polynesia', Decimal('200.00')),
#  ('Angola', 'Sub-Saharan Africa', 'Middle Africa', Decimal('1246700.00')),
#  ('Anguilla', 'Latin America and the Caribbean', 'Caribbean', None),
#  ('Antigua and Barbuda', 'Latin America and the Caribbean', 'Caribbean', Decimal('440.00')),
#  ('Argentina', 'Latin America and the Caribbean', 'South America', Decimal('2736690.00')),
#  ('Armenia', 'Northern Africa and Western Asia', 'Western Asia', Decimal('28470.00')),
#  ('Aruba', 'Latin America and the Caribbean', 'Caribbean', Decimal('180.00')),
#  ('Australia', 'Oceania', 'Australia and New Zealand', Decimal('7690400.00')),
# ...
