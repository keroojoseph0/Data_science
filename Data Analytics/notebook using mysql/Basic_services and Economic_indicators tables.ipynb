# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:SecureP%40sw0rd%21123@localhost:3306/united_nations

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 50;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 50 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
# ...

# %% [markdown]
# ## 1. Create a table that contains data about access to basic services for each country and year only.

# %%
# %%sql
#
# CREATE TABLE Basic_services (
#     Country_name VARCHAR(255),
#     Time_period VARCHAR(255),
#     Pct_managed_drinking_water_services DECIMAL(5, 2),
#     Pct_managed_sanitation_services DECIMAL(5, 2),
#     PRIMARY KEY (Country_name ,Time_period)
# );
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 0 rows affected.
# []

# %%
# %%sql
#
# INSERT INTO Basic_services (Country_name, Time_period, Pct_managed_drinking_water_services, Pct_managed_sanitation_services)
# SELECT Country_name, Time_period, Pct_managed_drinking_water_services, Pct_managed_sanitation_services
# FROM Access_to_Basic_Services
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM Basic_services;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Afghanistan', '2015', Decimal('67.00'), Decimal('45.67')),
#  ('Afghanistan', '2016', Decimal('69.67'), Decimal('47.00')),
#  ('Afghanistan', '2017', Decimal('72.33'), Decimal('49.33')),
#  ('Afghanistan', '2018', Decimal('75.33'), Decimal('50.67')),
#  ('Afghanistan', '2019', Decimal('78.00'), Decimal('52.33')),
#  ('Afghanistan', '2020', Decimal('80.33'), Decimal('54.00')),
#  ('Algeria', '2015', Decimal('92.00'), Decimal('85.00')),
#  ('Algeria', '2016', Decimal('93.00'), Decimal('85.33')),
#  ('Algeria', '2017', Decimal('93.00'), Decimal('84.67')),
#  ('Algeria', '2018', Decimal('93.00'), Decimal('84.67')),
#  ('Algeria', '2019', Decimal('93.33'), Decimal('84.67')),
#  ('Algeria', '2020', Decimal('93.33'), Decimal('84.33')),
#  ('American Samoa', '2015', Decimal('100.00'), Decimal('57.00')),
#  ('American Samoa', '2016', Decimal('100.00'), Decimal('56.00')),
# ...

# %% [markdown]
# ## 2. Create a table that contains the economic indicators.

# %%
# %%sql
#
# CREATE TABLE Economic_indicators (
#     Country_name VARCHAR(255),
#     Time_period VARCHAR(255),
#     Est_gdp_in_billions DECIMAL(5, 2),
#     Est_population_in_millions DECIMAL(5, 2),
#     Pct_unemployment DECIMAL(5, 2),
#     PRIMARY KEY (Country_name, Time_period)
# );
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 0 rows affected.
# []

# %%
# %%sql
#
# SELECT
#     MAX(Est_gdp_in_billions)
# FROM Access_to_Basic_Services
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1 rows affected.
# [(Decimal('14687.67'),)]

# %%
# %%sql
#
# ALTER TABLE Economic_indicators MODIFY Est_gdp_in_billions DECIMAL(8, 2);
# ALTER TABLE Economic_indicators MODIFY Est_population_in_millions DECIMAL(8, 2);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
#
# INSERT INTO Economic_indicators (Country_name, Time_period, Est_gdp_in_billions, Est_population_in_millions, Pct_unemployment)
# SELECT Country_name, Time_period, Est_gdp_in_billions, Est_population_in_millions, Pct_unemployment
# FROM Access_to_Basic_Services
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM Economic_indicators
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Afghanistan', '2015', Decimal('20.00'), Decimal('33.75'), None),
#  ('Afghanistan', '2016', Decimal('18.02'), Decimal('34.64'), None),
#  ('Afghanistan', '2017', Decimal('18.90'), Decimal('35.64'), Decimal('11.18')),
#  ('Afghanistan', '2018', Decimal('18.42'), Decimal('36.69'), None),
#  ('Afghanistan', '2019', Decimal('18.90'), Decimal('37.77'), None),
#  ('Afghanistan', '2020', Decimal('20.14'), Decimal('38.97'), Decimal('11.71')),
#  ('Algeria', '2015', Decimal('165.98'), Decimal('39.54'), Decimal('11.21')),
#  ('Algeria', '2016', Decimal('160.03'), Decimal('40.34'), Decimal('10.20')),
#  ('Algeria', '2017', Decimal('170.10'), Decimal('41.14'), Decimal('12.00')),
#  ('Algeria', '2018', Decimal('174.91'), Decimal('41.93'), None),
#  ('Algeria', '2019', Decimal('171.77'), Decimal('42.71'), None),
#  ('Algeria', '2020', Decimal('145.01'), Decimal('43.45'), None),
# ...
